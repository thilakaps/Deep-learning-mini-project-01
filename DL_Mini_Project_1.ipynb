# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import RMSprop
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cv2
import os

from google.colab import drive
drive.mount('/content/drive')

os.chdir("/content/drive/My Drive/DL-1/")
os.getcwd()

img = image.load_img("Training/GA/ga (1).JPG")

plt.imshow(img)

cv2.imread("Training/GA/ga (1).JPG").shape

train = ImageDataGenerator(rescale = 1/255)

validation = ImageDataGenerator(rescale = 1/255)

train_dataset = train.flow_from_directory('Training/',
                                          target_size = (200,200),
                                          batch_size = 3,
                                          class_mode = 'binary')

validation_dataset = validation.flow_from_directory('Validation/',
                                                   target_size = (200,200),
                                                   batch_size = 3,
                                                   class_mode = 'binary')

train_dataset.class_indices

train_dataset.classes

model = tf.keras.models.Sequential([tf.keras.layers.Conv2D(16,(3,3),activation = 'relu',input_shape = (200,200,3)),
                                   # MaxPooling layer with pool size (2, 2)
                                    tf.keras.layers.MaxPool2D(2,2),
                                   # Convolutional layer with 32 filters, each of size (3, 3), and ReLU activation
                                    tf.keras.layers.Conv2D(32,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                   # Convolutional layer with 64 filters, each of size (3, 3), and ReLU activation
                                    tf.keras.layers.Conv2D(64,(3,3),activation = 'relu'),
                                    tf.keras.layers.MaxPool2D(2,2),
                                   # Flatten layer to convert 3D feature maps to 1D feature vectors
                                    tf.keras.layers.Flatten(),
                                   # Dense (fully connected) layer with 512 units and ReLU activation
                                    tf.keras.layers.Dense(512,activation = 'relu'),
                                   # Output layer with 1 unit and sigmoid activation for binary classification
                                    tf.keras.layers.Dense(1,activation = 'sigmoid')
                                    ])

model.compile(loss = 'binary_crossentropy',
              optimizer = RMSprop(lr=0.001),
              metrics = ['accuracy'])



model_fit = model.fit(train_dataset,
                      steps_per_epoch = 5,
                      epochs = 30,
                      validation_data = validation_dataset)


validation_dataset.class_indices

dir_path = 'Testing/'

for i in os.listdir(dir_path):
    # Load the image and resize it to the target size
  img = image.load_img(dir_path+ i,target_size=(200,200))
  # Display the image using matplotlib
  plt.imshow(img)
  plt.show()

  # Convert the image to a NumPy array and add an extra dimension
  X = image.img_to_array(img)
  X = np.expand_dims(X,axis = 0)
# Stack the array vertically to create a batch of images
  images = np.vstack([X])
# Make a prediction using the trained model
  val = model.predict(images)
# Check the predicted value and print the corresponding class label
  if val == 0:
    print("This is Letter 'Ga' in Sinhala")
  else:
    print("This is Letter 'Ya' in Sinhala")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Found 120 images belonging to 2 classes.
# Found 120 images belonging to 2 classes.
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.RMSprop.
# Epoch 1/30
# 5/5 [==============================] - 7s 1s/step - loss: 5.1992 - accuracy: 0.3333 - val_loss: 0.9779 - val_accuracy: 0.5000
# Epoch 2/30
# 5/5 [==============================] - 5s 1s/step - loss: 1.0388 - accuracy: 0.4000 - val_loss: 0.6899 - val_accuracy: 0.5000
# Epoch 3/30
# 5/5 [==============================] - 7s 2s/step - loss: 0.6996 - accuracy: 0.3333 - val_loss: 1.0421 - val_accuracy: 0.5000
# Epoch 4/30
# 5/5 [==============================] - 5s 1s/step - loss: 1.4019 - accuracy: 0.4667 - val_loss: 0.6758 - val_accuracy: 0.5000
# Epoch 5/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.6970 - accuracy: 0.4667 - val_loss: 0.6475 - val_accuracy: 0.7500
# Epoch 6/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.6063 - accuracy: 0.7333 - val_loss: 1.9231 - val_accuracy: 0.5000
# Epoch 7/30
# 5/5 [==============================] - 7s 2s/step - loss: 0.7726 - accuracy: 0.7333 - val_loss: 0.5417 - val_accuracy: 0.7250
# Epoch 8/30
# 5/5 [==============================] - 4s 855ms/step - loss: 0.5306 - accuracy: 0.7333 - val_loss: 0.6832 - val_accuracy: 0.5500
# Epoch 9/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.4790 - accuracy: 0.8667 - val_loss: 0.4857 - val_accuracy: 0.7333
# Epoch 10/30
# 5/5 [==============================] - 4s 865ms/step - loss: 1.4228 - accuracy: 0.6000 - val_loss: 0.4596 - val_accuracy: 0.7667
# Epoch 11/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.5013 - accuracy: 0.8000 - val_loss: 0.4148 - val_accuracy: 0.8250
# Epoch 12/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.6293 - accuracy: 0.7333 - val_loss: 0.3983 - val_accuracy: 0.8167
# Epoch 13/30
# 5/5 [==============================] - 7s 2s/step - loss: 0.5661 - accuracy: 0.6667 - val_loss: 0.4868 - val_accuracy: 0.8333
# Epoch 14/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.4535 - accuracy: 0.8667 - val_loss: 0.3738 - val_accuracy: 0.8750
# Epoch 15/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.2495 - accuracy: 0.9333 - val_loss: 0.3665 - val_accuracy: 0.8333
# Epoch 16/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.3780 - accuracy: 0.8667 - val_loss: 0.2567 - val_accuracy: 0.8917
# Epoch 17/30
# 5/5 [==============================] - 4s 859ms/step - loss: 0.2171 - accuracy: 0.9333 - val_loss: 0.2951 - val_accuracy: 0.8583
# Epoch 18/30
# 5/5 [==============================] - 4s 954ms/step - loss: 0.3059 - accuracy: 0.8667 - val_loss: 0.2906 - val_accuracy: 0.8750
# Epoch 19/30
# 5/5 [==============================] - 4s 863ms/step - loss: 0.4506 - accuracy: 0.9333 - val_loss: 0.2445 - val_accuracy: 0.9000
# Epoch 20/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.0999 - accuracy: 1.0000 - val_loss: 0.1884 - val_accuracy: 0.9333
# Epoch 21/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.1021 - accuracy: 1.0000 - val_loss: 0.1956 - val_accuracy: 0.9083
# Epoch 22/30
# 5/5 [==============================] - 4s 864ms/step - loss: 0.1647 - accuracy: 0.9333 - val_loss: 0.2328 - val_accuracy: 0.9000
# Epoch 23/30
# 5/5 [==============================] - 8s 2s/step - loss: 0.1692 - accuracy: 0.8667 - val_loss: 0.2664 - val_accuracy: 0.8833
# Epoch 24/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.1145 - accuracy: 1.0000 - val_loss: 0.2423 - val_accuracy: 0.8917
# Epoch 25/30
# 5/5 [==============================] - 7s 2s/step - loss: 0.1378 - accuracy: 0.9333 - val_loss: 0.2480 - val_accuracy: 0.8750
# Epoch 26/30
# 5/5 [==============================] - 4s 862ms/step - loss: 0.5769 - accuracy: 0.7333 - val_loss: 0.2244 - val_accuracy: 0.9083
# Epoch 27/30
# 5/5 [==============================] - 6s 1s/step - loss: 0.1471 - accuracy: 0.9333 - val_loss: 0.1703 - val_accuracy: 0.9333
# Epoch 28/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.3989 - accuracy: 0.8667 - val_loss: 0.1492 - val_accuracy: 0.9500
# Epoch 29/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.0935 - accuracy: 1.0000 - val_loss: 0.1423 - val_accuracy: 0.9167
# Epoch 30/30
# 5/5 [==============================] - 5s 1s/step - loss: 0.1051 - accuracy: 0.9333 - val_loss: 0.4439 - val_accuracy: 0.8667
# 1/1 [==============================] - 0s 94ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 33ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 33ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 52ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 51ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 49ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 51ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 52ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 50ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 51ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 33ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 46ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 44ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 36ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 34ms/step
# This is Letter 'Ya' in Sinhala
# 1/1 [==============================] - 0s 35ms/step
# This is Letter 'Ga' in Sinhala
# 1/1 [==============================] - 0s 33ms/step
# This is Letter 'Ga' in Sinhala
